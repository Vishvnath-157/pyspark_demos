# %%
sc
# Out:
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=8974218609267045#setting/sparkui/0208-041747-ya5sqww8/driver-7519367160619444414">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %%
display(dbutils.fs.ls("/FileStore/tables/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
files_loc= '/FileStore/tables/'

flights_small= files_loc + 'flights_small.csv'
planes = files_loc + 'planes.csv'
airport= files_loc + 'airports.csv'

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, FloatType
from pyspark.sql.functions import *

# %%
flights_small_df= spark.read.csv(flights_small, inferSchema = True, header = True)
display(flights_small_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
planes_df= spark.read.csv(planes, inferSchema = True, header = True)
display(planes_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
airport_df= spark.read.csv(airport, inferSchema = True, header = True)
display(airport_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
spark.catalog.listTables()
# Out:
# Out[30]: [Table(name='airport_df', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True),
#  Table(name='flights', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True),
#  Table(name='flights_small_df', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True),
#  Table(name='planes_df', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True)]

# %%
)
# Out:
# Out[22]: [Table(name='flights', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True),
#  Table(name='flights_small_df', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True)]

# %%
# Out:
# Out[24]: [Table(name='flights', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True),
#  Table(name='flights_small_df', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True),
#  Table(name='planes_df', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True)]

# %%
# Out:
# Out[25]: [Table(name='airport_df', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True),
#  Table(name='flights', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True),
#  Table(name='flights_small_df', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True),
#  Table(name='planes_df', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True)]

# %%
# Filter flights with a SQL string

long_flights= flights_small_df.filter('distance > 1000')
long_flights.show()
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|dest|air_time|distance|hour|minute|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+
# |2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA| HNL|     360|    2677|  10|    40|
# |2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA| SAN|     135|    1050|  12|    36|
# |2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA| ORD|     198|    1721|  18|    12|
# |2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA| PHX|     154|    1107|  11|    20|
# |2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA| ANC|     183|    1448|  23|    46|
# ...

# %%
# Filter flights with a boolean column
long_flights2 = flights_small_df.filter(flights_small_df.distance > 1000 )
long_flights2.show()
# Out:
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|dest|air_time|distance|hour|minute|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+
# |2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA| HNL|     360|    2677|  10|    40|
# |2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA| SAN|     135|    1050|  12|    36|
# |2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA| ORD|     198|    1721|  18|    12|
# |2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA| PHX|     154|    1107|  11|    20|
# |2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA| ANC|     183|    1448|  23|    46|
# ...

# %%
avg_distance= flights_small_df.filter(flights_small_df.distance/(flights_small_df.air_time)).alias(average_speed)
speed_1= flights_small_df.select('origin','dest','tailnum',avg_distance)
avg_distance.show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-2678016722320241> in <cell line: 1>()
# ----> 1 avg_distance= flights_small_df.filter(flights_small_df.distance/(flights_small_df.air_time)).alias(average_speed)
#       2 speed_1= flights_small_df.select('origin','dest','tailnum',avg_distance)
#       3 avg_distance.show()
#
# /databricks/spark/python/pyspark/instrumentation_utils.py in wrapper(*args, **kwargs)
#      46             start = time.perf_counter()
#      47             try:
# ---> 48                 res = func(*args, **kwargs)
#      49                 logger.log_success(
#      50                     module_name, class_name, function_name, time.perf_counter() - start, signature
#
# /databricks/spark/python/pyspark/sql/dataframe.py in filter(self, condition)
#    2163             jdf = self._jdf.filter(condition)
# ...

# %%
speed_2 =flights_small_df.selectExpr('origin','dest','tailnum','distance/(air_time/60) as avg_speed')
speed_2.show()
# Out:
# +------+----+-------+------------------+
# |origin|dest|tailnum|         avg_speed|
# +------+----+-------+------------------+
# |   SEA| LAX| N846VA| 433.6363636363636|
# |   SEA| HNL| N559AS| 446.1666666666667|
# |   SEA| SFO| N847VA|367.02702702702703|
# |   PDX| SJC| N360SW| 411.3253012048193|
# |   SEA| BUR| N612AS| 442.6771653543307|
# |   PDX| DEN| N646SW|491.40495867768595|
# |   PDX| OAK| N422WN|             362.0|
# |   SEA| SFO| N361VA| 415.7142857142857|
# |   SEA| SAN| N309AS| 466.6666666666667|
# |   SEA| ORD| N564AS| 521.5151515151515|
# |   SEA| LAX| N323AS| 440.3076923076923|
# |   SEA| PHX| N305AS|431.29870129870125|
# |   SEA| LAS| N433AS| 409.6062992125984|
# |   SEA| ANC| N765AS|474.75409836065575|
# |   SEA| SFO| N713AS| 315.8139534883721|
# |   PDX| SFO| N27205| 366.6666666666667|
# |   SEA| SMF| N626AS|477.63157894736844|
# |   SEA| MDW| N8634A|481.38888888888886|
# |   SEA| BOS| N597AS| 516.4137931034483|
# |   PDX| BUR| N215AG| 441.6216216216216|
# ...

# %%
flights_small_df.describe()
# Out:
# Out[43]: DataFrame[summary: string, year: string, month: string, day: string, dep_time: string, dep_delay: string, arr_time: string, arr_delay: string, carrier: string, tailnum: string, flight: string, origin: string, dest: string, air_time: string, distance: string, hour: string, minute: string]

# %%
#Find the length of the longest (in terms of time) flight that left SEA


max_time= flights_small_df.filter(flights_small_df.origin=='SEA').groupBy().max(flights_small_df.air_time)
max_time.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <command-474953797480262> in <cell line: 4>()
#       2
#       3
# ----> 4 max_time= flights_small_df.filter(flights_small_df.origin=='SEA').groupBy().max(flights_small_df.air_time)
#       5 max_time.show()
#
# /databricks/spark/python/pyspark/instrumentation_utils.py in wrapper(*args, **kwargs)
#      46             start = time.perf_counter()
#      47             try:
# ---> 48                 res = func(*args, **kwargs)
#      49                 logger.log_success(
#      50                     module_name, class_name, function_name, time.perf_counter() - start, signature
#
# /databricks/spark/python/pyspark/sql/group.py in _api(self, *cols)
#      48     def _api(self: "GroupedData", *cols: str) -> DataFrame:
#      49         name = f.__name__
# ...
