# %%
df = spark.read.csv("s3://readingdatafroms3//*.csv")
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <command-859996219694850> in <cell line: 1>()
# ----> 1 df = spark.read.csv("s3://readingdatafroms3//*.csv")
#
# /databricks/spark/python/pyspark/instrumentation_utils.py in wrapper(*args, **kwargs)
#      46             start = time.perf_counter()
#      47             try:
# ---> 48                 res = func(*args, **kwargs)
#      49                 logger.log_success(
#      50                     module_name, class_name, function_name, time.perf_counter() - start, signature
#
# ...

# %%
access_key = "AKIA36DQLJC5CIB2SDEY"
secret_key = "lDl+1oCOm3mj4UdqSY2ZPVHHOVCSBHcM20olKOhW"

#Mount bucket on databricks
encoded_secret_key = secret_key.replace("/", "%2F")
aws_bucket_name = "readingdatafroms3"
mount_name = "S3ondatabricks"
dbutils.fs.mount("s3a://%s:%s@%s" % (access_key, encoded_secret_key, aws_bucket_name), "/mnt/%s" % mount_name)
display(dbutils.fs.ls("/mnt/%s" % mount_name))
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# <command-859996219694851> in <cell line: 8>()
#       6 aws_bucket_name = "readingdatafroms3"
#       7 mount_name = "S3ondatabricks"
# ----> 8 dbutils.fs.mount("s3a://%s:%s@%s" % (access_key, encoded_secret_key, aws_bucket_name), "/mnt/%s" % mount_name)
#       9 display(dbutils.fs.ls("/mnt/%s" % mount_name))
#
# /databricks/python_shell/dbruntime/dbutils.py in f_with_exception_handling(*args, **kwargs)
#     360                     exc.__context__ = None
#     361                     exc.__cause__ = None
# --> 362                     raise exc
#     363
#     364             return f_with_exception_handling
#
# ExecutionError: An error occurred while calling o416.mount.
# : java.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/S3ondatabricks; nested exception is:
# ...

# %%
df = spark.read.csv("dbfs:/mnt/S3ondatabricks/*.csv", header=True,inferSchema = True)

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.count()
# Out:
# Out[40]: 17009

# %%
# Out:
# Out[12]: Row(Date=None, Data Last Updated=None, Data Run=None, IMS Account ID=None, Account Name=None, IMS Account Type=None, IBM Account Type=None, Datacenter=None, Server Room=None, Rack Number=None, POD=None, Hardware Status=None, Hardware Status Duration (Days)=None, Hardware Age (Months)=None, Motherboard Model=None, Chassis Name=None, Chassis Size=None, Processor Code=None, Processor Version Code=None, RAM Total Capacity=None, RAM Description=None, Drive Description=None, Drive Controller Description=None, GPU Description=None, Hostname=None, Domain Name=None, Hardware ID=None, Hardware Internal Serial Number=None, Hardware Count=None, Product Package ID=None, Product Package Primary Description=None, Full SKU=None)

# %%
df.columns
# Out:
# Out[41]: ['Date',
#  'Data Last Updated',
#  'Data Run',
#  'IMS Account ID',
#  'Account Name',
#  'IMS Account Type',
#  'IBM Account Type',
#  'Datacenter',
#  'Server Room',
#  'Rack Number',
#  'POD',
#  'Hardware Status',
#  'Hardware Status Duration (Days)',
#  'Hardware Age (Months)',
#  'Motherboard Model',
#  'Chassis Name',
#  'Chassis Size',
#  'Processor Code',
#  'Processor Version Code',
#  'RAM Total Capacity',
#  'RAM Description',
#  'Drive Description',
#  'Drive Controller Description',
#  'GPU Description',
#  'Hostname',
#  'Domain Name',
#  'Hardware ID',
#  'Hardware Internal Serial Number',
#  'Hardware Count',
#  'Product Package ID',
#  'Product Package Primary Description',
#  'Full SKU']

# %%
print(df.collect()[5000])
# Out:
# Row(Date='9/30/22', Data Last Updated='9/30/22 11:59 PM', Data Run='10/01/2022 07:53:13 AM', IMS Account ID=2257212, Account Name='us-south.prod.ibm', IMS Account Type='Customer', IBM Account Type='Internal', Datacenter='DAL13', Server Room=3, Rack Number=84, POD='DAL13 - 3', Hardware Status='Active', Hardware Status Duration (Days)='23', Hardware Age (Months)=19, Motherboard Model='X11DPU+_R1.10', Chassis Name='SMCH04', Chassis Size=1, Processor Code=5218, Processor Version Code=None, RAM Total Capacity=384, RAM Description='DDR4:32:2933 REG(12)', Drive Description='SATAIII:1920GB:MLC(1), SATAIII:2000:7200:Exos 7E8(1), SATAIII:3840GB:SED(1)', Drive Controller Description='SATA/SAS - MegaRAID SAS 9461-16i SGL(1)', GPU Description='Not Applicable', Hostname='kube-c1cvv8od0jmmqgrben10-a2ussouthpr-hot-0000f3e2', Domain Name='iks.ibm', Hardware ID=3190170, Hardware Internal Serial Number='SL01LI22', Hardware Count=1, Product Package ID=2696, Product Package Primary Description='Bare Meta
# ...

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
len(df.columns)
# Out:
# Out[43]: 32

# %%
df.distinct().count()
# Out:
# Out[44]: 17009

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <command-4289680754503370> in <cell line: 1>()
# ----> 1 df.shape()
#
# /databricks/spark/python/pyspark/instrumentation_utils.py in wrapper(*args, **kwargs)
#      46             start = time.perf_counter()
#      47             try:
# ---> 48                 res = func(*args, **kwargs)
#      49                 logger.log_success(
#      50                     module_name, class_name, function_name, time.perf_counter() - start, signature
#
# /databricks/spark/python/pyspark/sql/dataframe.py in __getattr__(self, name)
#    2072         """
#    2073         if name not in self.columns:
# -> 2074             raise AttributeError(
#    2075                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name)
#    2076             )
#
# AttributeError: 'DataFrame' object has no attribute 'shape'

# %%
type(df)
# Out:
# Out[36]: pyspark.sql.dataframe.DataFrame

# %%
ls
# Out:
# azure/  eventlogs/  hadoop_accessed_config.lst*  metastore_db/
# conf/   ganglia/    logs/                        preload_class.lst*

# %%
display(dbutils.fs.ls("/FileStore/tables/%s" % mount_name))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
